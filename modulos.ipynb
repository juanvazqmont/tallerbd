# %% [markdown]
# modulo 1
#
# path and big data map +toxtli talk
# http://es.slideshare.net/carlostoxtli/introduccion-a-data-science-la-guia-practica-para-volverse-data-scientist-42444759
#
# command line
# http://learncodethehardway.org/
# http://datascienceatthecommandline.com/
#
# git
# https://www.codecademy.com/learn/learn-git
# https://try.github.io/levels/1/challenges/1
#
# www.github.com
#
# lenguajes y APIs
# https://learnxinyminutes.com/
#
# data scrapping
# http://es.schoolofdata.org/introduccion-a-la-extraccion-de-datos-de-sitios-web-scraping/
# http://webscraper.io/
# https://www.import.io/
# https://github.com/sanshiro/scrape-it
#
#
# analisis exploratorio con vinos
# https://github.com/jadianes/data-science-your-way/blob/master/apps/wine-quality-data-analysis/README.md
#
#
# cleaning data (ejemplo del pdf a csv chagas)
#
#
# interpolacion de datos y predicciones complejas (ML)
# https://www.datacamp.com/courses/introduction-to-machine-learning-with-r/chapter-1-what-is-machine-learning-r
#
# machine learning con titanic y
# https://www.datacamp.com/community/open-courses
#
# http://trevorstephens.com/post/72916401642/titanic-getting-started-with-r
# https://github.com/trevorstephens/titanic
#
# http://www.r2d3.us/visual-intro-to-machine-learning-part-1/
# https://medium.com/@josemarcialportilla/enchanted-random-forest-b08d418cb411#.e1qwl97bs
#
# kaggle
# https://www.kaggle.com/c/expedia-hotel-recommendations
# https://www.dataquest.io/blog/kaggle-tutorial/
#
#
# diagrama de flujo de algoritmos de ML
# http://scikit-learn.org/stable/tutorial/machine_learning_map/index.html
#
# algunas tecnicas de machine learning con ejemplos: flores,
# http://scikit-learn.org/stable/auto_examples/index.html
# https://github.com/charlesjhlee/ml_ipynb
#
# datacamp examples, etc.
#
# herramientas principales: R, python, julia
# https://try.jupyter.org/
# https://www.continuum.io/blog/developer/jupyter-and-conda-r
#
# aplicaciones:
#
# dataviz R + d3.js. setosa
# https://plot.ly/r/using-r-in-jupyter-notebooks/
# http://setosa.io/#/
#
#
#
# fuentes para aprender
# www.datacamp.com
# www.dataquest.io
#
# temperaturas
# https://gist.github.com/jebyrnes/b34930da0052a86f5ffe254ce9900357
# http://www.fromthebottomoftheheap.net/2016/03/25/additive-modeling-global-temperature-series-revisited/
#
#
#
#
# modulo 2
#
# deep learning
# http://playground.tensorflow.org/
# http://deeplearning.net/software/theano/
# http://neuralnetworksanddeeplearning.com/ (libro)
#
# cuda y GPUs
# https://developer.nvidia.com/accelerated-computing-toolkit
#
#
#
# big data tools: mapreduce, hadoop, spark (pptx)
#
# scala
# blog.codacy.com/2015/07/03/how-to-learn-scala/
# https://www.toptal.com/scala/using-scala-js-with-npm-and-browserify
#
#
# spark,
# https://docs.continuum.io/anaconda-cluster/howto/spark-basic
# https://bigdatauniversity.com/courses/spark-fundamentals/
# https://github.com/hohonuuli/sparknotebook
#
#
# cloud computing
# http://streetscore.media.mit.edu/data.html
#
# aws example+
# https://eu-west-1.console.aws.amazon.com/machinelearning/home?region=eu-west-1#/
#
# google
# http://www.nypon.de/RoogleVision-released/
# http://flovv.github.io/Image-Recognition-Google-Vision/
# https://console.cloud.google.com/apis/credentials/oauthclient/299345194361-p1uheh35ngqremoquvhfldtoak6ehbjl.apps.googleusercontent.com?project=vision01r-1315
#
# azure
# http://gallery.cortanaintelligence.com/Experiment/01b2765fa75147ce99679e18482d280f
# https://studio.azureml.net/Home/ViewWorkspaceCached/fea7b35e52e54d78aff105d1792972de?#Workspaces/WebServiceGroups/WebServiceGroup/3aab1a10db6d4484afc6286dbea493c8/dashboard
#
# analytics examples
# http://www.elconfidencial.com/tecnologia/2013-12-01/conoce-el-valor-de-alquiler-y-venta-de-cualquier-casa-con-la-web-tercerob_60611/
#
#
# principales recursos para aprender
# https://www.coursera.org/specializations/big-data
# http://bigdatauniversity.com/learning-paths/
#
# recap
#
# big data colombia
# http://infovis.co/introToBigData/#/outline
#
# charla Ubando Plenum pptx
#
#
# anuncio hackbanero
# http://hackbanero.xyz/

# %%
plot(c(1,2,3,4,5),c(2,4,6,8,10))
# Out:
# plot without title
